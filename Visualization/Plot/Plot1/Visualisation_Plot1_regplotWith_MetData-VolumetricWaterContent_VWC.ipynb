# %%
# Seaborn visualization library
import seaborn as sns

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pandas import read_excel
from pandas import DataFrame

# %%
plot_file_path="../plotImages/"

plot_data_path="../plotData/"

# %%
#Plot the dataframe with the gas flux and the met data  - pairplot to see the correlation between the flux and the different met parameters

#Radiation Parameters

data_plot1_metVWC = read_excel('../PlotData/Plot1_GasFlux_MetData_SoilParams_VWC_Filtered.xlsx', sheet_name='Sheet1') #index_col=13, parse_dates=[13]

# %%
data_plot1_metVWC['Flux'].max()
# Out:
# 5148.4019

# %% [markdown]
# #### Error when using hue on pairplot for Seaborn version 0.10.0
# This works for Seaborn version 0.9.0
# The problem is linked with statsmodel - seaborn fails to capture all runtime errors linked with statsmodel in this new version
# https://github.com/mwaskom/seaborn/issues/1990

# %% [markdown]
# ###### CORRELATION BETWEEN PLOT 1 FLUX DATA AND MET DATA - Volumetric Water Content (VWC)
#
# VWC_1_1_1 =	Volumetric water capacity @ 5cm,
# VWC_2_1_1 =	Volumetric water capacity @ 10cm,
# VWC_3_1_1 =	Volumetric water capacity @ 15cm,
# VWC_4_1_1 =	Volumetric water capacity @ 25cm

# %%
data_plot1_metVWC
# Out:
#     TIMESTAMP_1_rounded      Flux      ghg flux_unit  VWC_1_1_1  VWC_2_1_1  \
# 0   2019-03-26 17:30:00 -144.0262  N2O_dry       mug      18.60      27.75
# 1   2019-03-26 17:30:00  -98.0130  CH4_dry       mug      18.60      27.75
# 2   2019-03-26 17:30:00 -466.8398  CO2_dry        mg      18.60      27.75
# 3   2019-03-26 22:00:00 -102.3469  N2O_dry       mug      18.80      27.50
# 4   2019-03-26 22:00:00  -25.5522  CH4_dry       mug      18.80      27.50
# ..                  ...       ...      ...       ...        ...        ...
# 829 2019-06-29 17:30:00  -74.6339  CH4_dry       mug      12.90      19.30
# 830 2019-06-29 17:30:00  540.0715  CO2_dry        mg      12.90      19.30
# 831 2019-06-29 22:00:00 -114.1416  N2O_dry       mug      12.85      19.30
# 832 2019-06-29 22:00:00  127.2111  CH4_dry       mug      12.85      19.30
# 833 2019-06-29 22:00:00  953.3316  CO2_dry        mg      12.85      19.30
#
#      VWC_3_1_1  VWC_4_1_1
# 0        30.25      36.05
# ...

# %%
sns.set(color_codes=True)

# %% [markdown]
# #### Functions to draw linear regression models - regplot, lmplot

# %% [markdown]
# ##### CORRELATION BETWEEN PLOT 1 FLUX DATA AND MET DATA - Volumetric Water Content ((VWC)
# VWC_1_1_1 =	Volumetric water capacity @ 5cm,
# VWC_2_1_1 =	Volumetric water capacity @ 10cm,
# VWC_3_1_1 =	Volumetric water capacity @ 15cm,
# VWC_4_1_1 =	Volumetric water capacity @ 25cm

# %%
sns.regplot(x="VWC_1_1_1", y="Flux", data=data_plot1_metVWC)

# %% [markdown]
# ##### Plot - regplot -
# VWC_1_1_1 = Volumetric water capacity @ 5cm, VWC_2_1_1 = Volumetric water capacity @ 10cm, VWC_3_1_1 = Volumetric water capacity @ 15cm, VWC_4_1_1 = Volumetric water capacity @ 25cm

# %%
#plot the different data frames

fig, (axs) = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(15,8))
fig.suptitle("Volumetric Water Content Parameters v/s Flux")

sns.regplot(x="VWC_1_1_1", y="Flux", data=data_plot1_metVWC, ax=axs[0,0], label="VWC_1_1_1", color='#40B790')
sns.regplot(x="VWC_2_1_1", y="Flux", data=data_plot1_metVWC, ax=axs[0,1], label="VWC_2_1_1", color="#6DA1E5")

sns.regplot(x="VWC_3_1_1", y="Flux", data=data_plot1_metVWC, ax=axs[1,0], label="VWC_3_1_1", color="#40B790")
sns.regplot(x="VWC_4_1_1", y="Flux", data=data_plot1_metVWC, ax=axs[1,1], label="VWC_4_1_1", color="#6DA1E5")

axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()

# %% [markdown]
# ##### Separate the gases

# %% [markdown]
# ##### N2O_dry

# %%
data_plot1_metVWC_N2Odry = data_plot1_metVWC[data_plot1_metVWC['ghg'] == 'N2O_dry']

# %%
data_plot1_metVWC_N2Odry
# Out:
#     TIMESTAMP_1_rounded      Flux      ghg flux_unit  VWC_1_1_1  VWC_2_1_1  \
# 0   2019-03-26 17:30:00 -144.0262  N2O_dry       mug      18.60      27.75
# 3   2019-03-26 22:00:00 -102.3469  N2O_dry       mug      18.80      27.50
# 6   2019-03-27 06:30:00  -93.0909  N2O_dry       mug      19.00      27.50
# 9   2019-03-28 20:30:00   63.8219  N2O_dry       mug      18.40      26.55
# 11  2019-03-30 02:30:00 -157.9453  N2O_dry       mug      18.40      25.75
# ..                  ...       ...      ...       ...        ...        ...
# 819 2019-06-29 00:30:00  -68.7106  N2O_dry       mug      13.30      20.30
# 822 2019-06-29 05:00:00  -96.2937  N2O_dry       mug      13.30      20.20
# 825 2019-06-29 13:30:00  -97.1944  N2O_dry       mug      13.00      19.65
# 828 2019-06-29 17:30:00 -125.4368  N2O_dry       mug      12.90      19.30
# 831 2019-06-29 22:00:00 -114.1416  N2O_dry       mug      12.85      19.30
#
#      VWC_3_1_1  VWC_4_1_1
# 0        30.25      36.05
# ...

# %%
#plot the different data frames

fig, (axs) = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(15,8))
fig.suptitle("Volumetric Water Content Parameters v/s N2O_dry")

sns.regplot(x="VWC_1_1_1", y="Flux", data=data_plot1_metVWC_N2Odry, ax=axs[0,0], label="VWC_1_1_1", color='#40B790')
sns.regplot(x="VWC_2_1_1", y="Flux", data=data_plot1_metVWC_N2Odry, ax=axs[0,1], label="VWC_2_1_1", color="#6DA1E5")

sns.regplot(x="VWC_3_1_1", y="Flux", data=data_plot1_metVWC_N2Odry, ax=axs[1,0], label="VWC_3_1_1", color="#40B790")
sns.regplot(x="VWC_4_1_1", y="Flux", data=data_plot1_metVWC_N2Odry, ax=axs[1,1], label="VWC_4_1_1", color="#6DA1E5")

fig.text(0.73, 1.0, ' VWC_1_1_1 = Volumetric water capacity @ 5cm \n \
VWC_2_1_1 = Volumetric water capacity @ 10cm \n \
VWC_3_1_1 = Volumetric water capacity @ 15cm \n \
VWC_4_1_1 = Volumetric water capacity @ 25cm', \
fontsize=16, color='darkblue'
)

axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()

#Save boxplot as a file
#output file name
output_file_name = "Plot1/Plot1_gasflux_N2Odry_SoilVWCMetData_regplot.png" 
plot_file_name = plot_file_path + output_file_name
# save as png
plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

# %% [markdown]
# ##### Note: There does not seem to be any linear relation between N2O_dry flux and Volumetric Water Content

# %% [markdown]
# ##### CH4_dry

# %%
data_plot1_metVWC_CH4dry = data_plot1_metVWC[data_plot1_metVWC['ghg'] == 'CH4_dry']

# %%
data_plot1_metVWC_CH4dry
# Out:
#     TIMESTAMP_1_rounded       Flux      ghg flux_unit  VWC_1_1_1  VWC_2_1_1  \
# 1   2019-03-26 17:30:00   -98.0130  CH4_dry       mug      18.60      27.75
# 4   2019-03-26 22:00:00   -25.5522  CH4_dry       mug      18.80      27.50
# 7   2019-03-27 06:30:00   -54.1259  CH4_dry       mug      19.00      27.50
# 12  2019-03-30 02:30:00   940.7205  CH4_dry       mug      18.40      25.75
# 15  2019-03-30 15:30:00   -59.4622  CH4_dry       mug      18.30      25.65
# ..                  ...        ...      ...       ...        ...        ...
# 820 2019-06-29 00:30:00   -90.5740  CH4_dry       mug      13.30      20.30
# 823 2019-06-29 05:00:00  5148.4019  CH4_dry       mug      13.30      20.20
# 826 2019-06-29 13:30:00  -114.9512  CH4_dry       mug      13.00      19.65
# 829 2019-06-29 17:30:00   -74.6339  CH4_dry       mug      12.90      19.30
# 832 2019-06-29 22:00:00   127.2111  CH4_dry       mug      12.85      19.30
#
#      VWC_3_1_1  VWC_4_1_1
# 1        30.25      36.05
# ...

# %%
#plot the different data frames

fig, (axs) = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(15,8))
fig.suptitle("Volumetric Water Content Parameters v/s CH4_dry")

sns.regplot(x="VWC_1_1_1", y="Flux", data=data_plot1_metVWC_CH4dry, ax=axs[0,0], label="VWC_1_1_1", color='#40B790')
sns.regplot(x="VWC_2_1_1", y="Flux", data=data_plot1_metVWC_CH4dry, ax=axs[0,1], label="VWC_2_1_1", color="#6DA1E5")

sns.regplot(x="VWC_3_1_1", y="Flux", data=data_plot1_metVWC_CH4dry, ax=axs[1,0], label="VWC_3_1_1", color="#40B790")
sns.regplot(x="VWC_4_1_1", y="Flux", data=data_plot1_metVWC_CH4dry, ax=axs[1,1], label="VWC_4_1_1", color="#6DA1E5")

fig.text(0.73, 1.0, ' VWC_1_1_1 = Volumetric water capacity @ 5cm \n \
VWC_2_1_1 = Volumetric water capacity @ 10cm \n \
VWC_3_1_1 = Volumetric water capacity @ 15cm \n \
VWC_4_1_1 = Volumetric water capacity @ 25cm', \
fontsize=16, color='darkblue'
)

axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()

#Save boxplot as a file
#output file name
output_file_name = "Plot1/Plot1_gasflux_CH4dry_SoilVWCMetData_regplot.png" 
plot_file_name = plot_file_path + output_file_name
# save as png
plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

# %% [markdown]
# ##### Note: There seems a direct linear relation between CH4_dry flux and Volumetric Water Content parameters

# %% [markdown]
# ##### CO2_dry

# %%
data_plot1_metVWC_CO2dry = data_plot1_metVWC[data_plot1_metVWC['ghg'] == 'CO2_dry']

# %%
data_plot1_metVWC_CO2dry
# Out:
#     TIMESTAMP_1_rounded       Flux      ghg flux_unit  VWC_1_1_1  VWC_2_1_1  \
# 2   2019-03-26 17:30:00  -466.8398  CO2_dry        mg      18.60      27.75
# 5   2019-03-26 22:00:00    91.8985  CO2_dry        mg      18.80      27.50
# 8   2019-03-27 06:30:00   308.7397  CO2_dry        mg      19.00      27.50
# 10  2019-03-28 20:30:00  -129.9216  CO2_dry        mg      18.40      26.55
# 13  2019-03-30 02:30:00   404.0616  CO2_dry        mg      18.40      25.75
# ..                  ...        ...      ...       ...        ...        ...
# 821 2019-06-29 00:30:00  1160.3080  CO2_dry        mg      13.30      20.30
# 824 2019-06-29 05:00:00   930.5471  CO2_dry        mg      13.30      20.20
# 827 2019-06-29 13:30:00   412.6364  CO2_dry        mg      13.00      19.65
# 830 2019-06-29 17:30:00   540.0715  CO2_dry        mg      12.90      19.30
# 833 2019-06-29 22:00:00   953.3316  CO2_dry        mg      12.85      19.30
#
#      VWC_3_1_1  VWC_4_1_1
# 2        30.25      36.05
# ...

# %%
#plot the different data frames

fig, (axs) = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(15,8))
fig.suptitle("Volumetric Water Content Parameters v/s CO2_dry")

sns.regplot(x="VWC_1_1_1", y="Flux", data=data_plot1_metVWC_CO2dry, ax=axs[0,0], label="VWC_1_1_1", color='#40B790')
sns.regplot(x="VWC_2_1_1", y="Flux", data=data_plot1_metVWC_CO2dry, ax=axs[0,1], label="VWC_2_1_1", color="#6DA1E5")

sns.regplot(x="VWC_3_1_1", y="Flux", data=data_plot1_metVWC_CO2dry, ax=axs[1,0], label="VWC_3_1_1", color="#40B790")
sns.regplot(x="VWC_4_1_1", y="Flux", data=data_plot1_metVWC_CO2dry, ax=axs[1,1], label="VWC_4_1_1", color="#6DA1E5")

fig.text(0.73, 1.0, ' VWC_1_1_1 = Volumetric water capacity @ 5cm \n \
VWC_2_1_1 = Volumetric water capacity @ 10cm \n \
VWC_3_1_1 = Volumetric water capacity @ 15cm \n \
VWC_4_1_1 = Volumetric water capacity @ 25cm', \
fontsize=16, color='darkblue'
)

axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()

#Save boxplot as a file
#output file name
output_file_name = "Plot1/Plot1_gasflux_CO2dry_SoilVWCMetData_regplot.png" 
plot_file_name = plot_file_path + output_file_name
# save as png
plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

# %% [markdown]
# ##### Note: There does not seem to be a linear relation between CO2_dry flux and Volumetric Water Content
