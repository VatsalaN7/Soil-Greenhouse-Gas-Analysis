# %%
# Seaborn visualization library
import seaborn as sns

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pandas import read_excel
from pandas import DataFrame

# %%
plot_file_path="../plotImages/"

plot_data_path="../plotData/"

# %%
#Plot the dataframe with the gas flux and the met data  - pairplot to see the correlation between the flux and the different met parameters

#Radiation Parameters

data_plot1_metSTP = read_excel('../PlotData/Plot1_GasFlux_MetData_SoilParams_STP_Filtered.xlsx', sheet_name='Sheet1') #index_col=13, parse_dates=[13]

# %%
data_plot1_metSTP['Flux'].max()
# Out:
# 5148.4019

# %% [markdown]
# #### Error when using hue on pairplot for Seaborn version 0.10.0
# This works for Seaborn version 0.9.0
# The problem is linked with statsmodel - seaborn fails to capture all runtime errors linked with statsmodel in this new version
# https://github.com/mwaskom/seaborn/issues/1990

# %% [markdown]
# ###### CORRELATION BETWEEN PLOT 1 FLUX DATA AND MET DATA - SOIL PARAMETERS (STP)
#
# STP_TSoil5_1_1_1 = Soil temperature @ 5cm
# STP_TSoil10_1_1_1 = Soil temperature @ 10cm
# STP_TSoil20_1_1_1 = Soil temperature @ 20cm
# STP_TSoil50_1_1_1 = Soil temperature @ 50cm

# %%
data_plot1_metSTP
# Out:
#     TIMESTAMP_1_rounded      Flux      ghg flux_unit  STP_TSoil_2_1_1_1  \
# 0   2019-03-26 17:30:00 -144.0262  N2O_dry       mug              8.530
# 1   2019-03-26 17:30:00  -98.0130  CH4_dry       mug              8.530
# 2   2019-03-26 17:30:00 -466.8398  CO2_dry        mg              8.530
# 3   2019-03-26 22:00:00 -102.3469  N2O_dry       mug              8.500
# 4   2019-03-26 22:00:00  -25.5522  CH4_dry       mug              8.500
# ..                  ...       ...      ...       ...                ...
# 829 2019-06-29 17:30:00  -74.6339  CH4_dry       mug             14.490
# 830 2019-06-29 17:30:00  540.0715  CO2_dry        mg             14.490
# 831 2019-06-29 22:00:00 -114.1416  N2O_dry       mug             14.575
# 832 2019-06-29 22:00:00  127.2111  CH4_dry       mug             14.575
# 833 2019-06-29 22:00:00  953.3316  CO2_dry        mg             14.575
#
#      STP_TSoil5_1_1_1  STP_TSoil10_1_1_1  STP_TSoil20_1_1_1  STP_TSoil50_1_1_1
# ...

# %%
sns.set(color_codes=True)

# %% [markdown]
# #### Functions to draw linear regression models - regplot, lmplot

# %% [markdown]
# ##### CORRELATION BETWEEN PLOT 1 FLUX DATA AND MET DATA - SOIL PARAMETERS
# STP_TSoil5_1_1_1 = Soil temperature @ 5cm
# STP_TSoil10_1_1_1 = Soil temperature @ 10cm
# STP_TSoil20_1_1_1 = Soil temperature @ 20cm
# STP_TSoil50_1_1_1 = Soil temperature @ 50cm

# %%
sns.regplot(x="STP_TSoil5_1_1_1", y="Flux", data=data_plot1_metSTP)

# %% [markdown]
# ##### Plot - regplot -
# STP_TSoil5_1_1_1 = Soil temperature @ 5cm
# STP_TSoil10_1_1_1 = Soil temperature @ 10cm
# STP_TSoil20_1_1_1 = Soil temperature @ 20cm
# STP_TSoil50_1_1_1 = Soil temperature @ 50cm

# %%
#plot the different data frames

fig, (axs) = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(15,8))
fig.suptitle("Soil (STP) Parameters v/s N2O_dry")

sns.regplot(x="STP_TSoil5_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[0,0], label="STP_TSoil5_1_1_1", color='#40B790')
sns.regplot(x="STP_TSoil10_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[0,1], label="STP_TSoil10_1_1_1", color="#6DA1E5")

sns.regplot(x="STP_TSoil20_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[1,0], label="STP_TSoil20_1_1_1", color="#40B790")
sns.regplot(x="STP_TSoil50_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[1,1], label="STP_TSoil50_1_1_1", color="#6DA1E5")

axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()

# %% [markdown]
# ##### Separate the gases

# %% [markdown]
# ##### N2O_dry

# %%
data_plot1_metSTP_N2Odry = data_plot1_metSTP[data_plot1_metSTP['ghg'] == 'N2O_dry']

# %%
data_plot1_metSTP_N2Odry
# Out:
#     TIMESTAMP_1_rounded      Flux      ghg flux_unit  STP_TSoil_2_1_1_1  \
# 0   2019-03-26 17:30:00 -144.0262  N2O_dry       mug              8.530
# 3   2019-03-26 22:00:00 -102.3469  N2O_dry       mug              8.500
# 6   2019-03-27 06:30:00  -93.0909  N2O_dry       mug              8.565
# 9   2019-03-28 20:30:00   63.8219  N2O_dry       mug              8.510
# 11  2019-03-30 02:30:00 -157.9453  N2O_dry       mug              8.710
# ..                  ...       ...      ...       ...                ...
# 819 2019-06-29 00:30:00  -68.7106  N2O_dry       mug             14.350
# 822 2019-06-29 05:00:00  -96.2937  N2O_dry       mug             14.435
# 825 2019-06-29 13:30:00  -97.1944  N2O_dry       mug             14.470
# 828 2019-06-29 17:30:00 -125.4368  N2O_dry       mug             14.490
# 831 2019-06-29 22:00:00 -114.1416  N2O_dry       mug             14.575
#
#      STP_TSoil5_1_1_1  STP_TSoil10_1_1_1  STP_TSoil20_1_1_1  STP_TSoil50_1_1_1
# ...

# %%
#plot the different data frames

fig, (axs) = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(15,8))
fig.suptitle("Soil STP Parameters v/s NO2_dry")

sns.regplot(x="STP_TSoil5_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[0,0], label="STP_TSoil5_1_1_1", color='#40B790')
sns.regplot(x="STP_TSoil10_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[0,1], label="STP_TSoil10_1_1_1", color="#6DA1E5")

sns.regplot(x="STP_TSoil20_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[1,0], label="STP_TSoil20_1_1_1", color="#40B790")
sns.regplot(x="STP_TSoil50_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[1,1], label="STP_TSoil50_1_1_1", color="#6DA1E5")

fig.text(0.73, 1.0, ' STP_TSoil_2_1_1_1 = Soil temperature @ 2cm \n \
STP_TSoil5_1_1_1 = Soil temperature @ 5cm \n \
STP_TSoil10_1_1_1 = Soil temperature @ 10cm \n \
STP_TSoil20_1_1_1 = Soil temperature @ 20cm \n \
STP_TSoil50_1_1_1 = Soil temperature @ 50cm', \
fontsize=16, color='darkblue'
)
axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()

#Save boxplot as a file
#output file name
output_file_name = "Plot1/Plot1_gasflux_N2Odry_SoilSTPMetData_regplot.png" 
plot_file_name = plot_file_path + output_file_name
# save as png
plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

# %% [markdown]
# ##### Note: N2O_dry - Seems to have a linear relation with Soil parameters (STP)

# %% [markdown]
# ##### CH4_dry

# %%
data_plot1_metSTP_CH4dry = data_plot1_metSTP[data_plot1_metSTP['ghg'] == 'CH4_dry']

# %%
data_plot1_metSTP_CH4dry
# Out:
#     TIMESTAMP_1_rounded       Flux      ghg flux_unit  STP_TSoil_2_1_1_1  \
# 1   2019-03-26 17:30:00   -98.0130  CH4_dry       mug              8.530
# 4   2019-03-26 22:00:00   -25.5522  CH4_dry       mug              8.500
# 7   2019-03-27 06:30:00   -54.1259  CH4_dry       mug              8.565
# 12  2019-03-30 02:30:00   940.7205  CH4_dry       mug              8.710
# 15  2019-03-30 15:30:00   -59.4622  CH4_dry       mug              8.740
# ..                  ...        ...      ...       ...                ...
# 820 2019-06-29 00:30:00   -90.5740  CH4_dry       mug             14.350
# 823 2019-06-29 05:00:00  5148.4019  CH4_dry       mug             14.435
# 826 2019-06-29 13:30:00  -114.9512  CH4_dry       mug             14.470
# 829 2019-06-29 17:30:00   -74.6339  CH4_dry       mug             14.490
# 832 2019-06-29 22:00:00   127.2111  CH4_dry       mug             14.575
#
#      STP_TSoil5_1_1_1  STP_TSoil10_1_1_1  STP_TSoil20_1_1_1  STP_TSoil50_1_1_1
# ...

# %%
#plot the different data frames

fig, (axs) = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(15,8))

fig.suptitle("Soil STP Parameters v/s CH4_dry")

sns.regplot(x="STP_TSoil5_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[0,0], label="STP_TSoil5_1_1_1", color='#40B790')
sns.regplot(x="STP_TSoil10_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[0,1], label="STP_TSoil10_1_1_1", color="#6DA1E5")

sns.regplot(x="STP_TSoil20_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[1,0], label="STP_TSoil20_1_1_1", color="#40B790")
sns.regplot(x="STP_TSoil50_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[1,1], label="STP_TSoil50_1_1_1", color="#6DA1E5")

fig.text(0.73, 1.0, ' STP_TSoil_2_1_1_1 = Soil temperature @ 2cm \n \
STP_TSoil5_1_1_1 = Soil temperature @ 5cm \n \
STP_TSoil10_1_1_1 = Soil temperature @ 10cm \n \
STP_TSoil20_1_1_1 = Soil temperature @ 20cm \n \
STP_TSoil50_1_1_1 = Soil temperature @ 50cm', \
fontsize=16, color='darkblue'
)

axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()

#Save boxplot as a file
#output file name
output_file_name = "Plot1/Plot1_gasflux_CH4dry_SoilSTPMetData_regplot.png" 
plot_file_name = plot_file_path + output_file_name
# save as png
plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

# %% [markdown]
# ##### Note: CH4_dry - Seems to have a linear relation with Soil parameters (STP)

# %% [markdown]
# ##### CO2_dry

# %%
data_plot1_metSTP_CO2dry = data_plot1_metSTP[data_plot1_metSTP['ghg'] == 'CO2_dry']

# %%
data_plot1_metSTP_CO2dry
# Out:
#     TIMESTAMP_1_rounded       Flux      ghg flux_unit  STP_TSoil_2_1_1_1  \
# 2   2019-03-26 17:30:00  -466.8398  CO2_dry        mg              8.530
# 5   2019-03-26 22:00:00    91.8985  CO2_dry        mg              8.500
# 8   2019-03-27 06:30:00   308.7397  CO2_dry        mg              8.565
# 10  2019-03-28 20:30:00  -129.9216  CO2_dry        mg              8.510
# 13  2019-03-30 02:30:00   404.0616  CO2_dry        mg              8.710
# ..                  ...        ...      ...       ...                ...
# 821 2019-06-29 00:30:00  1160.3080  CO2_dry        mg             14.350
# 824 2019-06-29 05:00:00   930.5471  CO2_dry        mg             14.435
# 827 2019-06-29 13:30:00   412.6364  CO2_dry        mg             14.470
# 830 2019-06-29 17:30:00   540.0715  CO2_dry        mg             14.490
# 833 2019-06-29 22:00:00   953.3316  CO2_dry        mg             14.575
#
#      STP_TSoil5_1_1_1  STP_TSoil10_1_1_1  STP_TSoil20_1_1_1  STP_TSoil50_1_1_1
# ...

# %%
#plot the different data frames

fig, (axs) = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(15,8))

fig.suptitle("Soil STP Parameters v/s CO2_dry")

sns.regplot(x="STP_TSoil5_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[0,0], label="STP_TSoil5_1_1_1", color='#40B790')
sns.regplot(x="STP_TSoil10_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[0,1], label="STP_TSoil10_1_1_1", color="#6DA1E5")

sns.regplot(x="STP_TSoil20_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[1,0], label="STP_TSoil20_1_1_1", color="#40B790")
sns.regplot(x="STP_TSoil50_1_1_1", y="Flux", data=data_plot1_metSTP, ax=axs[1,1], label="STP_TSoil50_1_1_1", color="#6DA1E5")

fig.text(0.73, 1.0, ' STP_TSoil_2_1_1_1 = Soil temperature @ 2cm \n \
STP_TSoil5_1_1_1 = Soil temperature @ 5cm \n \
STP_TSoil10_1_1_1 = Soil temperature @ 10cm \n \
STP_TSoil20_1_1_1 = Soil temperature @ 20cm \n \
STP_TSoil50_1_1_1 = Soil temperature @ 50cm', \
fontsize=16, color='darkblue'
)

axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()

#Save boxplot as a file
#output file name
output_file_name = "Plot1/Plot1_gasflux_CO2dry_SoilSTPMetData_regplot.png" 
plot_file_name = plot_file_path + output_file_name
# save as png
plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

# %% [markdown]
# ##### Note: CO2_dry - Seems to have a linear relation with Soil parameters (STP)
