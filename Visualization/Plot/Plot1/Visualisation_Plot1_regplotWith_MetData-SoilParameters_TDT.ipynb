# %%
# Seaborn visualization library
import seaborn as sns

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pandas import read_excel
from pandas import DataFrame

# %%
plot_file_path="../plotImages/"

plot_data_path="../plotData/"

# %%
#Plot the dataframe with the gas flux and the met data  - pairplot to see the correlation between the flux and the different met parameters

#Radiation Parameters

data_plot1_metTDT = read_excel('../PlotData/Plot1_GasFlux_MetData_SoilParams_TDT_Filtered.xlsx', sheet_name='Sheet1') #index_col=13, parse_dates=[13]

# %%
data_plot1_metTDT['Flux'].max()
# Out:
# 5148.4019

# %% [markdown]
# #### Error when using hue on pairplot for Seaborn version 0.10.0
# This works for Seaborn version 0.9.0
# The problem is linked with statsmodel - seaborn fails to capture all runtime errors linked with statsmodel in this new version
# https://github.com/mwaskom/seaborn/issues/1990

# %% [markdown]
# ###### CORRELATION BETWEEN PLOT 1 FLUX DATA AND MET DATA - SOIL PARAMETERS (STP)
#
# (Soil temperature @ 5cm, Soil temperature @ 10cm, Soil temperature @ 15cm, Soil temperature @ 25cm)

# %%
data_plot1_metTDT
# Out:
#     TIMESTAMP_1_rounded      Flux      ghg flux_unit  TDT1_Ts_1_1_1  \
# 0   2019-03-26 17:30:00 -144.0262  N2O_dry       mug           8.50
# 1   2019-03-26 17:30:00  -98.0130  CH4_dry       mug           8.50
# 2   2019-03-26 17:30:00 -466.8398  CO2_dry        mg           8.50
# 3   2019-03-26 22:00:00 -102.3469  N2O_dry       mug           8.90
# 4   2019-03-26 22:00:00  -25.5522  CH4_dry       mug           8.90
# ..                  ...       ...      ...       ...            ...
# 829 2019-06-29 17:30:00  -74.6339  CH4_dry       mug          16.00
# 830 2019-06-29 17:30:00  540.0715  CO2_dry        mg          16.00
# 831 2019-06-29 22:00:00 -114.1416  N2O_dry       mug          16.55
# 832 2019-06-29 22:00:00  127.2111  CH4_dry       mug          16.55
# 833 2019-06-29 22:00:00  953.3316  CO2_dry        mg          16.55
#
#      TDT2_Ts_1_1_1  TDT3_Ts_1_1_1  TDT4_Ts_1_1_1
# 0            10.15          12.05          13.60
# 1            10.15          12.05          13.60
# ...

# %%
sns.set(color_codes=True)

# %% [markdown]
# #### Functions to draw linear regression models - regplot, lmplot

# %% [markdown]
# ##### CORRELATION BETWEEN PLOT 1 FLUX DATA AND MET DATA - SOIL PARAMETERS (TDT
# Soil temperature @ 5cm, Soil temperature @ 10cm, Soil temperature @ 15cm, Soil temperature @ 25cm

# %%
sns.regplot(x="TDT1_Ts_1_1_1", y="Flux", data=data_plot1_metTDT)

# %% [markdown]
# ##### Plot - regplot -
# Soil temperature @ 5cm, Soil temperature @ 10cm, Soil temperature @ 15cm, Soil temperature @ 25cm

# %%
#plot the different data frames

fig, (axs) = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(15,8))
fig.suptitle("Soil (TDT) Parameters v/s Flux")

sns.regplot(x="TDT1_Ts_1_1_1", y="Flux", data=data_plot1_metTDT, ax=axs[0,0], label="TDT1_Ts_1_1_1", color='#40B790')
sns.regplot(x="TDT2_Ts_1_1_1", y="Flux", data=data_plot1_metTDT, ax=axs[0,1], label="TDT2_Ts_1_1_1", color="#6DA1E5")

sns.regplot(x="TDT3_Ts_1_1_1", y="Flux", data=data_plot1_metTDT, ax=axs[1,0], label="TDT3_Ts_1_1_1", color="#40B790")
sns.regplot(x="TDT4_Ts_1_1_1", y="Flux", data=data_plot1_metTDT, ax=axs[1,1], label="TDT4_Ts_1_1_1", color="#6DA1E5")

axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()

# %% [markdown]
# ##### Separate the gases

# %% [markdown]
# ##### N2O_dry

# %%
data_plot1_metTDT_N2Odry = data_plot1_metTDT[data_plot1_metTDT['ghg'] == 'N2O_dry']

# %%
data_plot1_metTDT_N2Odry
# Out:
#     TIMESTAMP_1_rounded      Flux      ghg flux_unit  TDT1_Ts_1_1_1  \
# 0   2019-03-26 17:30:00 -144.0262  N2O_dry       mug           8.50
# 3   2019-03-26 22:00:00 -102.3469  N2O_dry       mug           8.90
# 6   2019-03-27 06:30:00  -93.0909  N2O_dry       mug           8.80
# 9   2019-03-28 20:30:00   63.8219  N2O_dry       mug           9.05
# 11  2019-03-30 02:30:00 -157.9453  N2O_dry       mug           9.50
# ..                  ...       ...      ...       ...            ...
# 819 2019-06-29 00:30:00  -68.7106  N2O_dry       mug          15.95
# 822 2019-06-29 05:00:00  -96.2937  N2O_dry       mug          15.90
# 825 2019-06-29 13:30:00  -97.1944  N2O_dry       mug          15.70
# 828 2019-06-29 17:30:00 -125.4368  N2O_dry       mug          16.00
# 831 2019-06-29 22:00:00 -114.1416  N2O_dry       mug          16.55
#
#      TDT2_Ts_1_1_1  TDT3_Ts_1_1_1  TDT4_Ts_1_1_1
# 0            10.15          12.05          13.60
# 3             9.75           9.15           8.35
# ...

# %%
#plot the different data frames

fig, (axs) = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(15,8))
fig.suptitle("Soil (TDT) Parameters v/s N2O_dry")

sns.regplot(x="TDT1_Ts_1_1_1", y="Flux", data=data_plot1_metTDT_N2Odry, ax=axs[0,0], label="TDT1_Ts_1_1_1", color='#40B790')
sns.regplot(x="TDT2_Ts_1_1_1", y="Flux", data=data_plot1_metTDT_N2Odry, ax=axs[0,1], label="TDT2_Ts_1_1_1", color="#6DA1E5")

sns.regplot(x="TDT3_Ts_1_1_1", y="Flux", data=data_plot1_metTDT_N2Odry, ax=axs[1,0], label="TDT3_Ts_1_1_1", color="#40B790")
sns.regplot(x="TDT4_Ts_1_1_1", y="Flux", data=data_plot1_metTDT_N2Odry, ax=axs[1,1], label="TDT4_Ts_1_1_1", color="#6DA1E5")

fig.text(0.73, 1.0, ' TDT1_Ts_1_1_1 = Soil temperature @ 5cm \n \
TDT2_Ts_1_1_1 = Soil temperature @ 10cm \n \
TDT3_Ts_1_1_1 = Soil temperature @ 15cm \n \
TDT4_Ts_1_1_1 = Soil temperature @ 25cm', \
fontsize=16, color='darkblue'
)

axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()

#Save boxplot as a file
#output file name
output_file_name = "Plot1/Plot1_gasflux_N2Odry_SoilTDTMetData_regplot.png" 
plot_file_name = plot_file_path + output_file_name
# save as png
plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

# %% [markdown]
# ##### Note: There does not seem to be any linear relation between N2O_dry flux and Soil TDT parameters

# %% [markdown]
# ##### CH4_dry

# %%
data_plot1_metTDT_CH4dry = data_plot1_metTDT[data_plot1_metTDT['ghg'] == 'CH4_dry']

# %%
data_plot1_metTDT_CH4dry
# Out:
#     TIMESTAMP_1_rounded       Flux      ghg flux_unit  TDT1_Ts_1_1_1  \
# 1   2019-03-26 17:30:00   -98.0130  CH4_dry       mug           8.50
# 4   2019-03-26 22:00:00   -25.5522  CH4_dry       mug           8.90
# 7   2019-03-27 06:30:00   -54.1259  CH4_dry       mug           8.80
# 12  2019-03-30 02:30:00   940.7205  CH4_dry       mug           9.50
# 15  2019-03-30 15:30:00   -59.4622  CH4_dry       mug           8.90
# ..                  ...        ...      ...       ...            ...
# 820 2019-06-29 00:30:00   -90.5740  CH4_dry       mug          15.95
# 823 2019-06-29 05:00:00  5148.4019  CH4_dry       mug          15.90
# 826 2019-06-29 13:30:00  -114.9512  CH4_dry       mug          15.70
# 829 2019-06-29 17:30:00   -74.6339  CH4_dry       mug          16.00
# 832 2019-06-29 22:00:00   127.2111  CH4_dry       mug          16.55
#
#      TDT2_Ts_1_1_1  TDT3_Ts_1_1_1  TDT4_Ts_1_1_1
# 1            10.15          12.05          13.60
# ...

# %%
#plot the different data frames

fig, (axs) = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(15,8))
fig.suptitle("Soil (TDT) Parameters v/s CH4_dry")

sns.regplot(x="TDT1_Ts_1_1_1", y="Flux", data=data_plot1_metTDT_CH4dry, ax=axs[0,0], label="TDT1_Ts_1_1_1", color='#40B790')
sns.regplot(x="TDT2_Ts_1_1_1", y="Flux", data=data_plot1_metTDT_CH4dry, ax=axs[0,1], label="TDT2_Ts_1_1_1", color="#6DA1E5")

sns.regplot(x="TDT3_Ts_1_1_1", y="Flux", data=data_plot1_metTDT_CH4dry, ax=axs[1,0], label="TDT3_Ts_1_1_1", color="#40B790")
sns.regplot(x="TDT4_Ts_1_1_1", y="Flux", data=data_plot1_metTDT_CH4dry, ax=axs[1,1], label="TDT4_Ts_1_1_1", color="#6DA1E5")

fig.text(0.73, 1.0, ' TDT1_Ts_1_1_1 = Soil temperature @ 5cm \n \
TDT2_Ts_1_1_1 = Soil temperature @ 10cm \n \
TDT3_Ts_1_1_1 = Soil temperature @ 15cm \n \
TDT4_Ts_1_1_1 = Soil temperature @ 25cm', \
fontsize=16, color='darkblue'
)

axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()

#Save boxplot as a file
#output file name
output_file_name = "Plot1/Plot1_gasflux_CH4dry_SoilTDTMetData_regplot.png" 
plot_file_name = plot_file_path + output_file_name
# save as png
plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

# %% [markdown]
# ##### Note: There seems a direct linear relation between CH4_dry flux and Soil TDT parameters

# %% [markdown]
# ##### CO2_dry

# %%
data_plot1_metTDT_CO2dry = data_plot1_metTDT[data_plot1_metTDT['ghg'] == 'CO2_dry']

# %%
data_plot1_metTDT_CO2dry
# Out:
#     TIMESTAMP_1_rounded       Flux      ghg flux_unit  TDT1_Ts_1_1_1  \
# 2   2019-03-26 17:30:00  -466.8398  CO2_dry        mg           8.50
# 5   2019-03-26 22:00:00    91.8985  CO2_dry        mg           8.90
# 8   2019-03-27 06:30:00   308.7397  CO2_dry        mg           8.80
# 10  2019-03-28 20:30:00  -129.9216  CO2_dry        mg           9.05
# 13  2019-03-30 02:30:00   404.0616  CO2_dry        mg           9.50
# ..                  ...        ...      ...       ...            ...
# 821 2019-06-29 00:30:00  1160.3080  CO2_dry        mg          15.95
# 824 2019-06-29 05:00:00   930.5471  CO2_dry        mg          15.90
# 827 2019-06-29 13:30:00   412.6364  CO2_dry        mg          15.70
# 830 2019-06-29 17:30:00   540.0715  CO2_dry        mg          16.00
# 833 2019-06-29 22:00:00   953.3316  CO2_dry        mg          16.55
#
#      TDT2_Ts_1_1_1  TDT3_Ts_1_1_1  TDT4_Ts_1_1_1
# 2            10.15          12.05          13.60
# ...

# %%
#plot the different data frames

fig, (axs) = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(15,8))
fig.suptitle("Soil (TDT) Parameters v/s CO2_dry")

sns.regplot(x="TDT1_Ts_1_1_1", y="Flux", data=data_plot1_metTDT_CO2dry, ax=axs[0,0], label="TDT1_Ts_1_1_1", color='#40B790')
sns.regplot(x="TDT2_Ts_1_1_1", y="Flux", data=data_plot1_metTDT_CO2dry, ax=axs[0,1], label="TDT2_Ts_1_1_1", color="#6DA1E5")

sns.regplot(x="TDT3_Ts_1_1_1", y="Flux", data=data_plot1_metTDT_CO2dry, ax=axs[1,0], label="TDT3_Ts_1_1_1", color="#40B790")
sns.regplot(x="TDT4_Ts_1_1_1", y="Flux", data=data_plot1_metTDT_CO2dry, ax=axs[1,1], label="TDT4_Ts_1_1_1", color="#6DA1E5")

fig.text(0.73, 1.0, ' TDT1_Ts_1_1_1 = Soil temperature @ 5cm \n \
TDT2_Ts_1_1_1 = Soil temperature @ 10cm \n \
TDT3_Ts_1_1_1 = Soil temperature @ 15cm \n \
TDT4_Ts_1_1_1 = Soil temperature @ 25cm', \
fontsize=16, color='darkblue'
)

axs[0,0].legend()
axs[0,1].legend()
axs[1,0].legend()
axs[1,1].legend()

#Save boxplot as a file
#output file name
output_file_name = "Plot1/Plot1_gasflux_CO2dry_SoilTDTMetData_regplot.png" 
plot_file_name = plot_file_path + output_file_name
# save as png
plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

# %% [markdown]
# ##### Note: There does not seem to be a linear relation between CO2_dry flux and Soil TDT parameters
