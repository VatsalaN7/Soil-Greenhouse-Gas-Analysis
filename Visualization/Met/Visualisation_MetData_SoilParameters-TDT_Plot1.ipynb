# %%
import pandas as pd
import numpy as np
from pandas import read_excel
from pandas import DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
from calendar import day_abbr, month_abbr, mdays
import datetime
#from datetime import datetime
from fbprophet import Prophet
from sklearn.metrics import mean_squared_error, mean_absolute_error
plt.style.use('fivethirtyeight') # For plots

#Author: Vatsala

# %%
plot_file_path="../plotImages/"

plot_data_path="../plotData/"

# %%
#****** Note: Data has been QC-ed

#read met Data to get the units of the different measurements
met_data = read_excel('../metData/ASSIST_EH_Biomet_30mins_Merged_20200605.xlsx', sheet_name='ASSIST_EH_Biomet_30mins_Merged', header=0)  #index_col=0, parse_dates=[0]

# %%
print(met_data)
# Out:
#                TIMESTAMP_1    PPFD_1_1_1 SWin_1_1_1 SWout_1_1_1 LWin_1_1_1  \
# 0         yyyy-mm-dd HH:MM  umol+1m-2s-1     W+1m-2      W+1m-2     W+1m-2
# 1      2018-12-21 08:30:00         7.745      1.736       1.436     343.55
# 2      2018-12-21 09:00:00        18.115     7.6995      1.1595     353.75
# 3      2018-12-21 09:30:00         21.28     7.6915       0.864     351.45
# 4      2018-12-21 10:00:00        65.275     28.765      3.7425      350.4
# ...                    ...           ...        ...         ...        ...
# 25518  2020-06-04 23:00:00         0.002    -0.5485       0.497      333.4
# 25519  2020-06-04 23:30:00         0.004     -0.548      0.4845      336.4
# 25520  2020-06-05 00:00:00         0.004    -0.6595       0.378      339.2
# 25521  2020-06-05 00:30:00         0.007     -0.422      0.3765      345.8
# 25522  2020-06-05 01:00:00        0.0065     -0.609        0.36      344.7
#
# ...

# %%
metdata_unit = pd.DataFrame()

metdata_unit['metUnit'] = met_data.iloc[0,:]
metdata_unit
# Out:
#                             metUnit
# TIMESTAMP_1        yyyy-mm-dd HH:MM
# PPFD_1_1_1             umol+1m-2s-1
# SWin_1_1_1                   W+1m-2
# SWout_1_1_1                  W+1m-2
# LWin_1_1_1                   W+1m-2
# LWout_1_1_1                  W+1m-2
# Rnet_1_1_1                   W+1m-2
# G_1_1_1                      W+1m-2
# G_2_1_1                      W+1m-2
# Ta_1_1_1                          C
# RH_1_1_1                          %
# Pa_1_1_1                        KPa
# P_1_1_1                          mm
# STP_TSoil_2_1_1_1                 C
# STP_TSoil5_1_1_1                  C
# STP_TSoil10_1_1_1                 C
# STP_TSoil20_1_1_1                 C
# STP_TSoil50_1_1_1                 C
# TDT1_Ts_1_1_1                     C
# TDT2_Ts_1_1_1                     C
# TDT3_Ts_1_1_1                     C
# TDT4_Ts_1_1_1                     C
# VWC_1_1_1                         %
# VWC_2_1_1                         %
# VWC_3_1_1                         %
# ...

# %%
met_data
# Out:
#                TIMESTAMP_1    PPFD_1_1_1 SWin_1_1_1 SWout_1_1_1 LWin_1_1_1  \
# 0         yyyy-mm-dd HH:MM  umol+1m-2s-1     W+1m-2      W+1m-2     W+1m-2
# 1      2018-12-21 08:30:00         7.745      1.736       1.436     343.55
# 2      2018-12-21 09:00:00        18.115     7.6995      1.1595     353.75
# 3      2018-12-21 09:30:00         21.28     7.6915       0.864     351.45
# 4      2018-12-21 10:00:00        65.275     28.765      3.7425      350.4
# ...                    ...           ...        ...         ...        ...
# 25518  2020-06-04 23:00:00         0.002    -0.5485       0.497      333.4
# 25519  2020-06-04 23:30:00         0.004     -0.548      0.4845      336.4
# 25520  2020-06-05 00:00:00         0.004    -0.6595       0.378      339.2
# 25521  2020-06-05 00:30:00         0.007     -0.422      0.3765      345.8
# 25522  2020-06-05 01:00:00        0.0065     -0.609        0.36      344.7
#
# ...

# %%
#Drop the first row from the dataset
met_data.drop(met_data.index[0], inplace=True)  #with inplace=True, we do not need to reassign the statement to the dataframe

# %%
met_data
# Out:
#                TIMESTAMP_1 PPFD_1_1_1 SWin_1_1_1 SWout_1_1_1 LWin_1_1_1  \
# 1      2018-12-21 08:30:00      7.745      1.736       1.436     343.55
# 2      2018-12-21 09:00:00     18.115     7.6995      1.1595     353.75
# 3      2018-12-21 09:30:00      21.28     7.6915       0.864     351.45
# 4      2018-12-21 10:00:00     65.275     28.765      3.7425      350.4
# 5      2018-12-21 10:30:00    111.155     51.505      6.9765     349.05
# ...                    ...        ...        ...         ...        ...
# 25518  2020-06-04 23:00:00      0.002    -0.5485       0.497      333.4
# 25519  2020-06-04 23:30:00      0.004     -0.548      0.4845      336.4
# 25520  2020-06-05 00:00:00      0.004    -0.6595       0.378      339.2
# 25521  2020-06-05 00:30:00      0.007     -0.422      0.3765      345.8
# 25522  2020-06-05 01:00:00     0.0065     -0.609        0.36      344.7
#
#       LWout_1_1_1 Rnet_1_1_1  G_1_1_1  G_2_1_1 Ta_1_1_1  ... TDT2_Ts_1_1_1  \
# ...

# %%
#set the index of data to Timestamp
met_data.set_index('TIMESTAMP_1', inplace=True)
met_data
# Out:
#                     PPFD_1_1_1 SWin_1_1_1 SWout_1_1_1 LWin_1_1_1 LWout_1_1_1  \
# TIMESTAMP_1
# 2018-12-21 08:30:00      7.745      1.736       1.436     343.55      355.45
# 2018-12-21 09:00:00     18.115     7.6995      1.1595     353.75       361.8
# 2018-12-21 09:30:00      21.28     7.6915       0.864     351.45       360.6
# 2018-12-21 10:00:00     65.275     28.765      3.7425      350.4      360.85
# 2018-12-21 10:30:00    111.155     51.505      6.9765     349.05       361.7
# ...                        ...        ...         ...        ...         ...
# 2020-06-04 23:00:00      0.002    -0.5485       0.497      333.4       365.2
# 2020-06-04 23:30:00      0.004     -0.548      0.4845      336.4       364.7
# 2020-06-05 00:00:00      0.004    -0.6595       0.378      339.2      366.55
# 2020-06-05 00:30:00      0.007     -0.422      0.3765      345.8       367.8
# 2020-06-05 01:00:00     0.0065     -0.609        0.36      344.7      368.95
#
# ...

# %%
#Filter the dataframe to consider only a date range - applicable to the plots

#query = pd.Period('2009-12-28/2010-01-03', 'W-SUN')
#df.truncate(query.start_time, query.end_time)
#df[(df.index >= query.start_time) & (df.index <= query.end_time)]

met_data = met_data[(met_data.index >= '2019-03-26 17:26:00') & (met_data.index <= '2019-06-30 02:17:00')]
met_data
# Out:
#                     PPFD_1_1_1 SWin_1_1_1 SWout_1_1_1 LWin_1_1_1 LWout_1_1_1  \
# TIMESTAMP_1
# 2019-03-26 17:30:00      277.5     146.15       33.14      267.1      366.25
# 2019-03-26 18:00:00     124.15       67.9       13.15     266.45       357.3
# 2019-03-26 18:30:00      30.33     9.8225       1.458     280.85      341.65
# 2019-03-26 19:00:00     1.9145     -0.312      -0.069     315.65      345.15
# 2019-03-26 19:30:00     0.0145    -1.2475     -0.3645     317.05       345.2
# ...                        ...        ...         ...        ...         ...
# 2019-06-30 00:00:00     0.0045      -2.61       0.381     322.45       394.5
# 2019-06-30 00:30:00      0.004     -2.604      0.5075      314.7      391.65
# 2019-06-30 01:00:00     0.0045    -3.0015       0.454      304.9      387.85
# 2019-06-30 01:30:00     0.0045      -2.92        0.59     296.15       384.5
# 2019-06-30 02:00:00      0.005    -2.3615      0.5265     301.35      381.95
#
# ...

# %%
metdata_unit
# Out:
#                             metUnit
# TIMESTAMP_1        yyyy-mm-dd HH:MM
# PPFD_1_1_1             umol+1m-2s-1
# SWin_1_1_1                   W+1m-2
# SWout_1_1_1                  W+1m-2
# LWin_1_1_1                   W+1m-2
# LWout_1_1_1                  W+1m-2
# Rnet_1_1_1                   W+1m-2
# G_1_1_1                      W+1m-2
# G_2_1_1                      W+1m-2
# Ta_1_1_1                          C
# RH_1_1_1                          %
# Pa_1_1_1                        KPa
# P_1_1_1                          mm
# STP_TSoil_2_1_1_1                 C
# STP_TSoil5_1_1_1                  C
# STP_TSoil10_1_1_1                 C
# STP_TSoil20_1_1_1                 C
# STP_TSoil50_1_1_1                 C
# TDT1_Ts_1_1_1                     C
# TDT2_Ts_1_1_1                     C
# TDT3_Ts_1_1_1                     C
# TDT4_Ts_1_1_1                     C
# VWC_1_1_1                         %
# VWC_2_1_1                         %
# VWC_3_1_1                         %
# ...

# %%
#How to get data at one particular index value
print(metdata_unit.at['PPFD_1_1_1', 'metUnit'])
# Out:
# umol+1m-2s-1

# %%
#Plot the met data   - Soil Parameters (TDT)   X LABELS NOT DISPLAYED APPROPRIATELY
#plt.rcParams["figure.figsize"] = (20, 15)
#fig, axs = plt.subplots(2, 2)
#fig.suptitle('Met Data - Soil Parameters (TDT)', color = 'green')
#fig.tight_layout(pad=10.0)

##Find the unit of the particular plot
#unit = metdata_unit.at['TDT1_Ts_1_1_1', 'metUnit']
#axs[0, 0].plot(met_data.index, met_data['TDT1_Ts_1_1_1'], color = 'green')  #, edgecolor = 'darkblue'
#axs[0, 0].set_title('TDT1_Ts_1_1_1'+' in ('+unit+')', color = 'green')
#axs[0, 0].set_xticklabels(met_data.index, rotation=30, ha='right', color = 'green')

#unit = metdata_unit.at['TDT2_Ts_1_1_1', 'metUnit']
#axs[0, 1].plot(met_data.index, met_data['TDT2_Ts_1_1_1'], color = '#3333FF')  #, edgecolor = 'darkblue'
#axs[0, 1].set_title('TDT2_Ts_1_1_1'+' in ('+unit+')', color = '#3333FF')
#axs[0, 1].set_xticklabels(met_data.index, rotation=30, ha='right', color = '#3333FF')

#unit = metdata_unit.at['TDT3_Ts_1_1_1', 'metUnit']
#axs[1, 0].plot(met_data.index, met_data['TDT3_Ts_1_1_1'], color = '#9933FF')  #, edgecolor = 'darkblue'
#axs[1, 0].set_title('TDT3_Ts_1_1_1'+' in ('+unit+')', color = '#9933FF')
#axs[1, 0].set_xticklabels(met_data.index, rotation=30, ha='right', color = '#9933FF')

#unit = metdata_unit.at['TDT4_Ts_1_1_1', 'metUnit']
#axs[1, 1].plot(met_data.index, met_data['TDT4_Ts_1_1_1'], color = '#FF3399')  #, edgecolor = 'darkblue'
#axs[1, 1].set_title('TDT4_Ts_1_1_1'+' in ('+unit+')', color = '#FF3399')
#axs[1, 1].set_xticklabels(met_data.index, rotation=30, ha='right', color = '#FF3399')

#Save boxplot as a file
#output file name
#output_file_name = "Plot1/gasflux_MetData_SoilParameters_TDT.png" 
#plot_file_name = plot_file_path + output_file_name

# save as png
#plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

#plt.show()

# %%
met_data
# Out:
#                     PPFD_1_1_1 SWin_1_1_1 SWout_1_1_1 LWin_1_1_1 LWout_1_1_1  \
# TIMESTAMP_1
# 2019-03-26 17:30:00      277.5     146.15       33.14      267.1      366.25
# 2019-03-26 18:00:00     124.15       67.9       13.15     266.45       357.3
# 2019-03-26 18:30:00      30.33     9.8225       1.458     280.85      341.65
# 2019-03-26 19:00:00     1.9145     -0.312      -0.069     315.65      345.15
# 2019-03-26 19:30:00     0.0145    -1.2475     -0.3645     317.05       345.2
# ...                        ...        ...         ...        ...         ...
# 2019-06-30 00:00:00     0.0045      -2.61       0.381     322.45       394.5
# 2019-06-30 00:30:00      0.004     -2.604      0.5075      314.7      391.65
# 2019-06-30 01:00:00     0.0045    -3.0015       0.454      304.9      387.85
# 2019-06-30 01:30:00     0.0045      -2.92        0.59     296.15       384.5
# 2019-06-30 02:00:00      0.005    -2.3615      0.5265     301.35      381.95
#
# ...

# %%
print(met_data['Ta_1_1_1'].max())
# Out:
# 32.485

# %%
#from datetime import datetime, timedelta

x = datetime.datetime(2020, 5, 17, 16, 36) 


def hour_rounder(t):
    # Rounds to nearest hour by adding a timedelta hour if minute >= 30
    return (t.replace(second=0, microsecond=0, minute=0, hour=t.hour)
               +datetime.timedelta(hours=t.minute//30))

print(x)
print(hour_rounder(x))
# Out:
# 2020-05-17 16:36:00
# 2020-05-17 17:00:00

# %%
#from datetime import datetime, timedelta

x = datetime.datetime(2020, 5, 17, 16, 36) 


def hour_rounder(t):
    # Rounds to nearest hour by adding a timedelta hour if minute >= 30
    return (t.replace(second=0, microsecond=0, minute=0, hour=t.hour)
               +datetime.timedelta(minutes=15*(t.minute // 15)))

print(x)
print(hour_rounder(x))
# Out:
# 2020-05-17 16:36:00
# 2020-05-17 16:30:00

# %%
#test round function from dt

met_data1 = met_data.copy()
met_data1['TIMESTAMP_1_value'] = met_data1.index

#round the timestamp value to nearest quarter
#met_data1['TIMESTAMP_1_rounded'] = met_data1['TIMESTAMP_1_value'].dt.round('15min')

#round the timestamp value to nearest half hour
met_data1['TIMESTAMP_1_rounded'] = met_data1['TIMESTAMP_1_value'].dt.round('30min')

#Drop the column Timestamp - the rounded Timestamp value will be used for plotting
#met_data1.drop('TIMESTAMP_1_value', axis=1, inplace=True)

met_data1
# Out:
#                     PPFD_1_1_1 SWin_1_1_1 SWout_1_1_1 LWin_1_1_1 LWout_1_1_1  \
# TIMESTAMP_1
# 2019-03-26 17:30:00      277.5     146.15       33.14      267.1      366.25
# 2019-03-26 18:00:00     124.15       67.9       13.15     266.45       357.3
# 2019-03-26 18:30:00      30.33     9.8225       1.458     280.85      341.65
# 2019-03-26 19:00:00     1.9145     -0.312      -0.069     315.65      345.15
# 2019-03-26 19:30:00     0.0145    -1.2475     -0.3645     317.05       345.2
# ...                        ...        ...         ...        ...         ...
# 2019-06-30 00:00:00     0.0045      -2.61       0.381     322.45       394.5
# 2019-06-30 00:30:00      0.004     -2.604      0.5075      314.7      391.65
# 2019-06-30 01:00:00     0.0045    -3.0015       0.454      304.9      387.85
# 2019-06-30 01:30:00     0.0045      -2.92        0.59     296.15       384.5
# 2019-06-30 02:00:00      0.005    -2.3615      0.5265     301.35      381.95
#
# ...

# %%
#how to query a dataframe bwtween 2 dates
start_date = pd.to_datetime('3/26/2019 00:00')
end_date   = pd.to_datetime('4/1/2019 00:00')

print(met_data1.loc[(met_data1['TIMESTAMP_1_rounded'] > start_date) & (met_data1['TIMESTAMP_1_rounded'] < end_date)])
# Out:
#                     PPFD_1_1_1 SWin_1_1_1 SWout_1_1_1 LWin_1_1_1 LWout_1_1_1  \
# TIMESTAMP_1
# 2019-03-26 17:30:00      277.5     146.15       33.14      267.1      366.25
# 2019-03-26 18:00:00     124.15       67.9       13.15     266.45       357.3
# 2019-03-26 18:30:00      30.33     9.8225       1.458     280.85      341.65
# 2019-03-26 19:00:00     1.9145     -0.312      -0.069     315.65      345.15
# 2019-03-26 19:30:00     0.0145    -1.2475     -0.3645     317.05       345.2
# ...                        ...        ...         ...        ...         ...
# 2019-03-31 21:30:00      0.008     -3.153      0.2655     256.15       339.4
# 2019-03-31 22:00:00      0.005    -3.2155       0.229     250.75      335.75
# 2019-03-31 22:30:00      0.006     -3.249       0.287      247.7       332.8
# 2019-03-31 23:00:00      0.007      -3.25      0.3125      245.9      330.15
# 2019-03-31 23:30:00      0.006     -3.141       0.193      244.9      327.75
#
# ...

# %%
#round the timestamp values for Plot 1 to nearest 15 mins to get same timestamp
#read Plot 1 data
plot1_data = read_excel('../plotData/plotData_1.xlsx', sheet_name='Sheet1', index_col=13, parse_dates=[13])

# %%
print(plot1_data.head(10))
plot1_data.dtypes
# Out:
#                      QC  Plot_ID  DailyRep treatment       Date   pv      ghg  \
# DateTime
# 2019-03-26 17:26:00   0        1         4        F0 2019-03-26  ***  N2O_dry
# 2019-03-26 21:49:00   0        1         5        F0 2019-03-26  ***  N2O_dry
# 2019-03-27 06:28:00   0        1         1        F0 2019-03-27  ***  N2O_dry
# 2019-03-28 20:34:00   0        1         2        F0 2019-03-28    *  N2O_dry
# 2019-03-30 02:43:00   0        1         0        F0 2019-03-30  ***  N2O_dry
# 2019-03-30 15:27:00   0        1         2        F0 2019-03-30  ***  N2O_dry
# 2019-03-30 19:51:00   0        1         3        F0 2019-03-30   **  N2O_dry
# 2019-03-31 00:17:00   0        1         0        F0 2019-03-31  ***  N2O_dry
# 2019-03-31 04:43:00   0        1         1        F0 2019-03-31  ***  N2O_dry
# 2019-03-31 13:32:00   0        1         3        F0 2019-03-31  ***  N2O_dry
#
#                     unit      flux      r2   nrmse   podpu  epoch_time
# DateTime
# ...

# %%
#Extract only datetime and flux from the series
plot1_dataframe = DataFrame()

plot1_dataframe['Flux']      = plot1_data['flux']
plot1_dataframe['ghg']       = plot1_data['ghg']
plot1_dataframe['flux_unit'] = plot1_data['unit']
plot1_dataframe['Timestamp'] = plot1_data.index

#round the timestamp value to nearest quarter
#plot1_dataframe['TIMESTAMP_1_rounded'] = plot1_dataframe['Timestamp'].dt.round('15min')

#round the timestamp value to nearest half hour
plot1_dataframe['TIMESTAMP_1_rounded'] = plot1_dataframe['Timestamp'].dt.round('30min')

#Drop the column Timestamp - the rounded Timestamp value will be used for plotting
plot1_dataframe.drop('Timestamp', axis=1, inplace=True)

#Create new index
plot1_dataframe.reset_index(drop=True, inplace=True)
plot1_dataframe.set_index('TIMESTAMP_1_rounded', drop=True, append=False, inplace=True, verify_integrity=False)

plot1_dataframe
# Out:
#                          Flux      ghg flux_unit
# TIMESTAMP_1_rounded
# 2019-03-26 17:30:00 -144.0262  N2O_dry       mug
# 2019-03-26 22:00:00 -102.3469  N2O_dry       mug
# 2019-03-27 06:30:00  -93.0909  N2O_dry       mug
# 2019-03-28 20:30:00   63.8219  N2O_dry       mug
# 2019-03-30 02:30:00 -157.9453  N2O_dry       mug
# ...                       ...      ...       ...
# 2019-06-29 05:00:00  930.5471  CO2_dry        mg
# 2019-06-29 13:30:00  412.6364  CO2_dry        mg
# 2019-06-29 17:30:00  540.0715  CO2_dry        mg
# 2019-06-29 22:00:00  953.3316  CO2_dry        mg
# 2019-06-30 02:30:00  684.4827  CO2_dry        mg
#
# [858 rows x 3 columns]

# %% [markdown]
# Note: Met data consists of different variables - break the data into 3 different data sets - radiation parameters; air parameters; soil parameters

# %%
#bring together plot 1 and met data together (air parameters - G1111, G2111, Ta111, RH111, Pa111, P111), and plot

#get a slice of the met_data1 - for Soil Parameters (TDT)
met_data1_slice3_2 = met_data1[['TIMESTAMP_1_rounded', 'TDT1_Ts_1_1_1', 'TDT2_Ts_1_1_1', 'TDT3_Ts_1_1_1', 'TDT4_Ts_1_1_1']]

#Create new index
met_data1_slice3_2.reset_index(drop=True, inplace=True)
met_data1_slice3_2.set_index('TIMESTAMP_1_rounded', drop=True, append=False, inplace=True, verify_integrity=False)

#Filter out negative values from the dataframe
met_data1_slice3_2 = met_data1_slice3_2[(met_data1_slice3_2['TDT1_Ts_1_1_1'] >= 0.0) & \
                                        (met_data1_slice3_2['TDT2_Ts_1_1_1'] >= 0.0) & \
                                        (met_data1_slice3_2['TDT3_Ts_1_1_1'] >= 0.0) & \
                                        (met_data1_slice3_2['TDT4_Ts_1_1_1'] >= 0.0)]
                                    
met_data1_slice3_2.to_excel(plot_data_path+'MetData_SoilParams_TDT_Filtered.xlsx')
met_data1_slice3_2
# Out:
#                     TDT1_Ts_1_1_1 TDT2_Ts_1_1_1 TDT3_Ts_1_1_1 TDT4_Ts_1_1_1
# TIMESTAMP_1_rounded
# 2019-03-26 17:30:00           8.5         10.15         12.05          13.6
# 2019-03-26 18:00:00           8.5         10.25          11.8         12.55
# 2019-03-26 18:30:00          8.55          10.3          11.4          11.5
# 2019-03-26 19:00:00          8.65          10.3         10.95          10.7
# 2019-03-26 19:30:00           8.7         10.25         10.55          10.2
# ...                           ...           ...           ...           ...
# 2019-06-30 00:00:00         16.75         19.35         19.95         19.45
# 2019-06-30 00:30:00          16.8         19.25         19.65          19.1
# 2019-06-30 01:00:00          16.8         19.15          19.4         18.75
# 2019-06-30 01:30:00          16.8            19         19.15         18.45
# 2019-06-30 02:00:00          16.8         18.85          18.9         18.15
#
# [4494 rows x 4 columns]

# %%
plot1_dataframe
# Out:
#                          Flux      ghg flux_unit
# TIMESTAMP_1_rounded
# 2019-03-26 17:30:00 -144.0262  N2O_dry       mug
# 2019-03-26 22:00:00 -102.3469  N2O_dry       mug
# 2019-03-27 06:30:00  -93.0909  N2O_dry       mug
# 2019-03-28 20:30:00   63.8219  N2O_dry       mug
# 2019-03-30 02:30:00 -157.9453  N2O_dry       mug
# ...                       ...      ...       ...
# 2019-06-29 05:00:00  930.5471  CO2_dry        mg
# 2019-06-29 13:30:00  412.6364  CO2_dry        mg
# 2019-06-29 17:30:00  540.0715  CO2_dry        mg
# 2019-06-29 22:00:00  953.3316  CO2_dry        mg
# 2019-06-30 02:30:00  684.4827  CO2_dry        mg
#
# [858 rows x 3 columns]

# %%
#concatenate this sliced dataframe with plot1_dataframe  #NOTE concatenate does not work
#plot1_metdata_slice1 = pd.concat([met_data1_slice1, plot1_dataframe], ignore_index=False, sort=False)

#Merge dataframes- based on index
plot1_metdata_slice3_2 = plot1_dataframe.merge(met_data1_slice3_2, left_index=True, right_index=True, how='inner')

plot1_metdata_slice3_2.to_excel(plot_data_path+'Plot1_GasFlux_MetData_SoilParams_TDT_Filtered.xlsx')

plot1_metdata_slice3_2
# Out:
#                          Flux      ghg flux_unit TDT1_Ts_1_1_1 TDT2_Ts_1_1_1  \
# TIMESTAMP_1_rounded
# 2019-03-26 17:30:00 -144.0262  N2O_dry       mug           8.5         10.15
# 2019-03-26 17:30:00  -98.0130  CH4_dry       mug           8.5         10.15
# 2019-03-26 17:30:00 -466.8398  CO2_dry        mg           8.5         10.15
# 2019-03-26 22:00:00 -102.3469  N2O_dry       mug           8.9          9.75
# 2019-03-26 22:00:00  -25.5522  CH4_dry       mug           8.9          9.75
# ...                       ...      ...       ...           ...           ...
# 2019-06-29 17:30:00  -74.6339  CH4_dry       mug            16         19.95
# 2019-06-29 17:30:00  540.0715  CO2_dry        mg            16         19.95
# 2019-06-29 22:00:00 -114.1416  N2O_dry       mug         16.55          19.8
# 2019-06-29 22:00:00  127.2111  CH4_dry       mug         16.55          19.8
# 2019-06-29 22:00:00  953.3316  CO2_dry        mg         16.55          19.8
#
# ...

# %%
#Plot the merged dataframe   - Vertical Plot   - Soil Parameters (TDT)

#Plot the figures VERTICALLY
plt.rcParams["figure.figsize"] = (25, 20)
fig, axs = plt.subplots(5)
fig.suptitle('Greenhouse gas flux - Met Data/Soil Parameters/TDT', color = 'green', size=22)
fig.tight_layout(pad=7.0)

axs[0].plot(plot1_metdata_slice3_2.index, plot1_metdata_slice3_2['Flux'], color = 'green')  #, edgecolor = 'darkblue'
axs[0].set_title('Gas Flux in mug/mg', color = 'green')
#axs[0].set_xticklabels(plot1_metdata_slice3_2.index, rotation=30, ha='right', color = 'green')

unit = metdata_unit.at['TDT1_Ts_1_1_1', 'metUnit']
axs[1].plot(plot1_metdata_slice3_2.index, plot1_metdata_slice3_2['TDT1_Ts_1_1_1'],  color = 'blue')
axs[1].set_title('TDT1_Ts_1_1_1'+' in ('+unit+')', color = 'blue')
#axs[1].set_xticklabels(plot1_metdata_slice3_2.index, rotation=30, ha='right', color = 'blue')

unit = metdata_unit.at['TDT2_Ts_1_1_1', 'metUnit']
axs[2].plot(plot1_metdata_slice3_2.index, plot1_metdata_slice3_2['TDT2_Ts_1_1_1'],  color = 'red')
axs[2].set_title('TDT2_Ts_1_1_1'+' in ('+unit+')', color = 'red')
#axs[2].set_xticklabels(plot1_metdata_slice3_2.index, rotation=30, ha='right', color = 'red')

unit = metdata_unit.at['TDT3_Ts_1_1_1', 'metUnit']
axs[3].plot(plot1_metdata_slice3_2.index, plot1_metdata_slice3_2['TDT3_Ts_1_1_1'],  color = 'green')
axs[3].set_title('TDT3_Ts_1_1_1'+' in ('+unit+')', color = 'green')
#axs[3].set_xticklabels(plot1_metdata_slice3_2.index, rotation=30, ha='right', color = 'green')

unit = metdata_unit.at['TDT4_Ts_1_1_1', 'metUnit']
axs[4].plot(plot1_metdata_slice3_2.index, plot1_metdata_slice3_2['TDT4_Ts_1_1_1'],  color = 'black')
axs[4].set_title('TDT4_Ts_1_1_1'+' in ('+unit+')', color = 'black')
#axs[4].set_xticklabels(plot1_metdata_slice3_2.index, rotation=30, ha='right', color = 'black')

plt.setp(axs[0].get_xticklabels() + axs[1].get_xticklabels() + axs[2].get_xticklabels() +
         axs[3].get_xticklabels() + axs[4].get_xticklabels(), rotation=30, ha='right')

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.55)

#Save boxplot as a file
#output file name  
output_file_name = "Plot1/MetData_SoilParams_TDT_Plot1_gasflux_lineplot.png" 
plot_file_name = plot_file_path + output_file_name

# save as png
plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

plt.show()

# %%
#Separate the dataframe by greenhouse gas - and then plot (4 vertical plots - 3 gases + 1 met data)

plot1_metdata_slice3_2_N2Odry = plot1_metdata_slice3_2[plot1_metdata_slice3_2['ghg'] == "N2O_dry"]

plot1_metdata_slice3_2_CH4dry = plot1_metdata_slice3_2[plot1_metdata_slice3_2['ghg'] == "CH4_dry"]

plot1_metdata_slice3_2_CO2dry = plot1_metdata_slice3_2[plot1_metdata_slice3_2['ghg'] == "CO2_dry"]

plot1_metdata_slice3_2_N2Odry
# Out:
#                          Flux      ghg flux_unit TDT1_Ts_1_1_1 TDT2_Ts_1_1_1  \
# TIMESTAMP_1_rounded
# 2019-03-26 17:30:00 -144.0262  N2O_dry       mug           8.5         10.15
# 2019-03-26 22:00:00 -102.3469  N2O_dry       mug           8.9          9.75
# 2019-03-27 06:30:00  -93.0909  N2O_dry       mug           8.8           7.9
# 2019-03-28 20:30:00   63.8219  N2O_dry       mug          9.05         10.85
# 2019-03-30 02:30:00 -157.9453  N2O_dry       mug           9.5           9.3
# ...                       ...      ...       ...           ...           ...
# 2019-06-29 00:30:00  -68.7106  N2O_dry       mug         15.95          17.5
# 2019-06-29 05:00:00  -96.2937  N2O_dry       mug          15.9         16.45
# 2019-06-29 13:30:00  -97.1944  N2O_dry       mug          15.7          17.8
# 2019-06-29 17:30:00 -125.4368  N2O_dry       mug            16         19.95
# 2019-06-29 22:00:00 -114.1416  N2O_dry       mug         16.55          19.8
#
# ...

# %%
# Plot Soil Parameters - TDT

#2. plot the different data frames
#fig,ax = plt.subplots()
plt.figure(figsize=(33,25))   #25,14
plt.suptitle('Gas Flux for Plot 1 together with Met data/Soil Parameters/TDT - scatter plot', color='green', size=30)  #, y=1.12


plt.subplot(331)
plt.xticks(rotation=40, ha='right', fontsize=25)
plt.yticks(fontsize=25)
plt.title('N2Odry', color='green', fontsize=25)
plt.scatter(plot1_metdata_slice3_2_N2Odry.index, plot1_metdata_slice3_2_N2Odry['Flux'], color='green')

plt.subplot(332)
plt.xticks(rotation=40, ha='right', fontsize=25)
plt.yticks(fontsize=25)
plt.title('CH4dry', color='blue', fontsize=25)
plt.scatter(plot1_metdata_slice3_2_CH4dry.index, plot1_metdata_slice3_2_CH4dry['Flux'], color='blue')

plt.subplot(333)
plt.xticks(rotation=40, ha='right', fontsize=25)
plt.yticks(fontsize=25)
plt.title('CO2dry', color='purple', fontsize=25)
plt.scatter(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['Flux'], color='purple')

plt.subplot(334)
unit = metdata_unit.at['TDT1_Ts_1_1_1', 'metUnit']
plt.xticks(rotation=40, ha='right', fontsize=25)
plt.yticks(fontsize=25)
plt.title('TDT1_Ts_1_1_1'+' in ('+unit+')', color='purple', fontsize=25)
plt.scatter(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['TDT1_Ts_1_1_1'], color='purple')

plt.subplot(335)
unit = metdata_unit.at['TDT2_Ts_1_1_1', 'metUnit']
plt.xticks(rotation=40, ha='right', fontsize=25)
plt.yticks(fontsize=25)
plt.title('TDT2_Ts_1_1_1'+' in ('+unit+')', color='black', fontsize=25)
plt.scatter(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['TDT2_Ts_1_1_1'], color='black')

plt.subplot(337)
unit = metdata_unit.at['TDT3_Ts_1_1_1', 'metUnit']
plt.xticks(rotation=40, ha='right', fontsize=25)
plt.yticks(fontsize=25)
plt.title('TDT3_Ts_1_1_1'+' in ('+unit+')', color='red', fontsize=25)
plt.scatter(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['TDT3_Ts_1_1_1'], color='red')

plt.subplot(338)
unit = metdata_unit.at['TDT4_Ts_1_1_1', 'metUnit']
plt.xticks(rotation=40, ha='right', fontsize=25)
plt.yticks(fontsize=25)
plt.title('TDT4_Ts_1_1_1'+' in ('+unit+')', color='blue', fontsize=25)
plt.scatter(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['TDT4_Ts_1_1_1'], color='blue')

plt.tight_layout()

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.55)

#Save boxplot as a file
#output file name
output_file_name = "Plot1/MetData_SoilParams_TDT_Plot1_gasflux_3gases_v1.png" 
plot_file_name = plot_file_path + output_file_name

# save as png
plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')
plt.show()

# %%
# Create two subplots and unpack the output array immediately  - Soil Parameters TDT   - NOT WORKING
#f, ((ax1, ax2, ax3),(ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, sharey=True, figsize=(36,30))
#f.tight_layout(pad=7.0)

#ax1.scatter(plot1_metdata_slice3_2_N2Odry.index, plot1_metdata_slice3_2_N2Odry['Flux'], color='green')
#ax1.set_title('N2Odry', color='green', fontsize=30)
#ax1.set_xticklabels(plot1_metdata_slice3_2_N2Odry.index, rotation=30, ha='right', fontsize=25)
##ax1.set_yticklabels(plot1_metdata_slice2_N2Odry['Flux'], fontsize=25)
#ax1.set_ylim(-2000, 1000)

#ax2.scatter(plot1_metdata_slice3_2_CH4dry.index, plot1_metdata_slice3_2_CH4dry['Flux'], color='blue')
#ax2.set_title('CH4dry', color='blue', fontsize=30)
#ax2.set_xticklabels(plot1_metdata_slice3_2_CH4dry.index, rotation=30, ha='right',  fontsize=25)

#ax3.scatter(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['Flux'], color='purple')
#ax3.set_title('CO2dry', color='purple', fontsize=30)
#ax3.set_xticklabels(plot1_metdata_slice3_2_CO2dry.index, rotation=30, ha='right', fontsize=25)

#unit = metdata_unit.at['TDT1_Ts_1_1_1', 'metUnit']
#ax4.plot(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['TDT1_Ts_1_1_1'], color='indigo')
#ax4.set_title('TDT1_Ts_1_1_1'+' in ('+unit+')', color='indigo', fontsize=30)
#ax4.set_xticklabels(plot1_metdata_slice3_2_CO2dry.index, rotation=30, ha='right', fontsize=25)

#unit = metdata_unit.at['TDT2_Ts_1_1_1', 'metUnit']
#ax5.plot(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['TDT2_Ts_1_1_1'], color='black')
#ax5.set_title('TDT2_Ts_1_1_1'+' in ('+unit+')', color='black', fontsize=30)
#ax5.set_xticklabels(plot1_metdata_slice3_2_CO2dry.index, rotation=30, ha='right', fontsize=25)

#unit = metdata_unit.at['TDT3_Ts_1_1_1', 'metUnit']
#ax7.plot(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['TDT3_Ts_1_1_1'], color='red')
#xa7.set_title('TDT3_Ts_1_1_1'+' in ('+unit+')', color='red', fontsize=30)
#ax7.set_xticklabels(plot1_metdata_slice3_2_CO2dry.index, rotation=30, ha='right', fontsize=25)

#unit = metdata_unit.at['TDT4_Ts_1_1_1', 'metUnit']
#ax8.plot(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['TDT4_Ts_1_1_1'], color='green')
#ax8.set_title('TDT4_Ts_1_1_1'+' in ('+unit+')', color='green', fontsize=30)
#ax8.set_xticklabels(plot1_metdata_slice3_2_CO2dry.index, rotation=30, ha='right', fontsize=25)

#plt.tight_layout()

##Save boxplot as a file
##output file name
#output_file_name = "Plot1/MetData_SoilParams_TDT_Plot1_gasflux-3gases-v2.png" 
#plot_file_name   = plot_file_path + output_file_name

## save as png
#plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

#plt.show()

# %%
#2. plot the different data frames    - Soil Parameters (TDT)
#fig,ax = plt.subplots()
plt.figure(figsize=(25,18))
plt.suptitle('Gas Flux for Plot 1 together with Met data/Soil Parameters (TDT) - scatter plot', color='green', fontsize=22) #, y=1.12
plt.tight_layout(pad=3.0)

plt.subplot(421)
plt.xticks(rotation=25, ha='right')
plt.title('N2Odry', color='green')
plt.scatter(plot1_metdata_slice3_2_N2Odry.index, plot1_metdata_slice3_2_N2Odry['Flux'], color='green')

plt.subplot(422)
plt.xticks(rotation=25, ha='right')
plt.title('CH4dry', color='blue')
plt.scatter(plot1_metdata_slice3_2_CH4dry.index, plot1_metdata_slice3_2_CH4dry['Flux'], color='blue')

plt.subplot(423)
plt.xticks(rotation=25, ha='right')
plt.title('CO2dry', color='purple')
plt.scatter(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['Flux'], color='purple')

plt.subplot(424)
unit = metdata_unit.at['TDT1_Ts_1_1_1', 'metUnit']
plt.xticks(rotation=25, ha='right')
plt.title('TDT1_Ts_1_1_1'+' in ('+unit+')', color='purple')
plt.scatter(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['TDT1_Ts_1_1_1'], color='purple')


plt.subplot(425)
unit = metdata_unit.at['TDT2_Ts_1_1_1', 'metUnit']
plt.xticks(rotation=25, ha='right')
plt.title('TDT2_Ts_1_1_1'+' in ('+unit+')', color='red')
plt.scatter(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['TDT2_Ts_1_1_1'], color='red')

plt.subplot(426)
unit = metdata_unit.at['TDT3_Ts_1_1_1', 'metUnit']
plt.xticks(rotation=25, ha='right')
plt.title('TDT3_Ts_1_1_1'+' in ('+unit+')', color='blue')
plt.scatter(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['TDT3_Ts_1_1_1'], color='blue')

plt.subplot(427)
unit = metdata_unit.at['TDT4_Ts_1_1_1', 'metUnit']
plt.xticks(rotation=25, ha='right')
plt.title('TDT4_Ts_1_1_1'+' in ('+unit+')', color='black')
plt.scatter(plot1_metdata_slice3_2_CO2dry.index, plot1_metdata_slice3_2_CO2dry['TDT4_Ts_1_1_1'], color='black')

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.55)

#Save boxplot as a file
#output file name
output_file_name = "Plot1/MetData_SoilParams_TDT_Plot1_gasflux_3gases_v2.png" 
plot_file_name = plot_file_path + output_file_name

# save as png
plt.savefig(plot_file_name, dpi=50, bbox_inches='tight')

plt.show()
